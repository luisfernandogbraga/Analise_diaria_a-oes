# %% [markdown]
# <a href="https://colab.research.google.com/github/luisfernandogbraga/Analise_diaria_acoes/blob/main/xxxx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 15.60
resultado = x + 6 + 16.4 + 4.4 + 22.4 + 6.6
print(round(resultado,2))
# Out:
# 71.4

# %%
import yfinance as yf

# %%
acao= 'CAML3.SA'
preco= yf.Ticker(acao).history(period='6mo')
historico= preco['Close']

primeiro_preco = historico[0]
ultimo_preco = historico[-1]

porcentagem_mudanca = ((ultimo_preco - primeiro_preco) / primeiro_preco) * 100

if porcentagem_mudanca > 0:
    print(f"A ação teve um aumento de {porcentagem_mudanca:.2f}% durante o período.")
elif porcentagem_mudanca < 0:
    print(f"A ação teve uma queda de {(porcentagem_mudanca):.2f}% durante o período.")
else:
    print("Não houve mudança no preço da ação durante o período.")
historico.plot()
# Out:
# A ação teve um aumento de 4.55% durante o período.
# <Axes: xlabel='Date'>
